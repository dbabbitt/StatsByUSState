# %% [markdown]
# # Set up the notebook

# %%
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
import sys

# Insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../py')

from choropleth_utils import ChoroplethUtilities
from stats_scraping_utils import StatsScrapingUtilities
from storage import Storage
import pandas as pd
import re
import os
import numpy as np

s = Storage()
ssu = StatsScrapingUtilities(s=s)

# %%
column_description_dict = s.load_object('column_description_dict')
us_stats_df = s.load_object('us_stats_df')

all_countries_df = s.load_object('all_countries_df').set_index('country_code', drop=True)
all_countries_df.country_name = all_countries_df.country_name.map(lambda x: ssu.country_name_dict.get(x, x))
s.store_objects(all_countries_df=all_countries_df.reset_index(drop=False))
# Out:
# Pickling to C:\Users\daveb\OneDrive\Documents\GitHub\StatsByCountry\saves\pkl\all_countries_df.pkl

# %% [markdown]
# ----
# # Get State/Country Cost of Living Equivalents

# %% [markdown]
# ## Clean and prepare US States dataset

# %%
url = 'https://meric.mo.gov/data/cost-living-data-series'
tables_list = ssu.get_page_tables(url)
# Out:
# [(1, (6, 8)), (0, (0, 9))]

# %%
body_opener_str = '</thead>\n  <tbody>\n  '
head_closer_str = '<th>Misc.</th>\n    </tr>\n    '
html_str = tables_list[0].to_html().replace(body_opener_str, '').replace(head_closer_str,
                                                                         head_closer_str + body_opener_str).replace('th>', 'td>')
tables_list = ssu.get_page_tables(html_str)
# Out:
# [(0, (52, 10))]

# %%
us_states_df = tables_list[0].copy()
# print(us_states_df.columns.tolist())
floats_list = ['cost_of_living_index', 'grocery_index', 'housing_index', 'utilities_index', 'transportation_index',
                'health_index', 'misc_index']
columns_list = ['cost_of_living_rank', 'state_name'] + floats_list
us_states_df.columns = ['deleteme'] + columns_list
us_states_df = us_states_df[columns_list]
for cn in floats_list:
    us_states_df[cn] = us_states_df[cn].map(lambda x: re.sub(r'[^0-9\.]+', '', str(x)))
    us_states_df[cn] = pd.to_numeric(us_states_df[cn], errors='coerce', downcast='float')
mask_series = us_states_df.state_name.isnull()
us_states_df = us_states_df[~mask_series]
us_states_df.head(10).T
# Out:
#                                 0          1           2           3  \
# cost_of_living_rank             1          2           3           4
# state_name            Mississippi   Oklahoma      Kansas     Alabama
# cost_of_living_index    83.099998  84.800003   85.400002        87.5
# grocery_index           92.300003       94.0   91.699997        97.0
# housing_index           63.799999  68.800003   68.199997   68.900002
# utilities_index              90.0  95.199997   98.699997  101.099998
# transportation_index    89.099998  90.300003   94.199997        90.0
# health_index            97.400002  92.900002  102.800003        90.5
# misc_index                   92.0  89.699997   90.400002        95.5
#
#                               4          5           6          7          8  \
# cost_of_living_rank           5          6           7          8          9
# state_name                 Iowa    Georgia     Indiana  Tennessee   Arkansas
# cost_of_living_index  88.099998  88.199997   89.199997  89.400002  89.900002
# grocery_index         99.400002  94.099998   93.400002       94.5  92.900002
# housing_index              69.5  74.199997   75.900002  80.699997  76.699997
# utilities_index       94.800003  91.199997  100.800003  94.099998       96.5
# transportation_index  93.400002  91.400002   97.099998  87.900002       94.5
# health_index          99.099998  94.300003   95.400002  91.699997  80.099998
# misc_index            95.599998  96.699997   93.800003  93.800003  99.699997
#
#                               9
# cost_of_living_rank          10
# state_name             Michigan
# cost_of_living_index  89.900002
# grocery_index         90.400002
# housing_index         77.800003
# utilities_index       98.199997
# transportation_index  95.699997
# health_index               97.0
# misc_index            96.599998

# %%
# Remove DC from the comparison so it doesn't skew the results
mask_series = (us_states_df.state_name.isin(['District of Columbia', '***']))
us_states_df = us_states_df[~mask_series]

# %%
# Remove US states duplicates and misspellings
states_list = sorted(set(us_states_df.state_name).symmetric_difference(set(ssu.us_stats_df.index)))
print(states_list)
doubles_df = ssu.check_4_doubles(states_list)
mask_series = (doubles_df.max_similarity > 0.6)
columns_list = ['first_item', 'second_item', 'max_similarity']
if doubles_df[mask_series].shape[0]:
    display(doubles_df[mask_series][columns_list].sort_values('max_similarity', ascending=False))
mask_series = us_states_df.duplicated(subset=['state_name'], keep=False)
if us_states_df[mask_series].shape[0]:
    display(us_states_df[mask_series])
# Out:
# ['District of Columbia']

# %% [markdown]
# ## Clean and prepare Countries dataset

# %%
url = 'https://www.numbeo.com/cost-of-living/rankings_by_country.jsp'
tables_list = ssu.get_page_tables(url)
# Out:
# [(1, (137, 8)), (0, (1, 2))]

# %%
countries_df = tables_list[1].copy()
# print(countries_df.columns.tolist())
floats_list = ['cost_of_living_index', 'rent_index', 'cost_of_living_plus_rent_index', 'groceries_index',
               'restaurant_price_index', 'local_purchasing_power_index']
columns_list = ['country_name'] + floats_list
countries_df.columns = ['cost_of_living_rank'] + columns_list
for cn in floats_list:
    countries_df[cn] = countries_df[cn].map(lambda x: re.sub(r'[^0-9\.]+', '', str(x)))
    countries_df[cn] = pd.to_numeric(countries_df[cn], errors='coerce', downcast='float')
mask_series = countries_df.country_name.isnull()
countries_df = countries_df[~mask_series][columns_list]
# countries_df.country_name = countries_df.country_name.map(lambda x: str(x).split('*')[0].strip())
countries_df.head(9).T
# Out:
#                                          0            1          2          3  \
# country_name                       Bermuda  Switzerland    Bahamas   Barbados
# cost_of_living_index            141.740005   110.339996  88.269997      87.07
# rent_index                       98.959999    50.209999      38.41      21.16
# cost_of_living_plus_rent_index  121.389999    81.730003  64.550003  55.709999
# groceries_index                 142.619995   113.349998  71.919998  81.730003
# restaurant_price_index          144.740005   104.300003  94.290001       74.5
# local_purchasing_power_index     82.339996   116.190002  44.220001  32.619999
#
#                                         4          5          6          7  \
# country_name                      Iceland     Norway     Jersey  Singapore
# cost_of_living_index            86.589996      85.93  80.379997  79.089996
# rent_index                      35.810001  30.549999  55.369999  65.089996
# cost_of_living_plus_rent_index      62.43      59.59  68.480003      72.43
# groceries_index                 82.440002  81.309998  64.519997  71.360001
# restaurant_price_index          88.639999  87.589996  89.230003  52.200001
# local_purchasing_power_index    82.620003  86.269997  68.720001  94.650002
#
#                                         8
# country_name                       Israel
# cost_of_living_index            77.279999
# rent_index                      32.950001
# cost_of_living_plus_rent_index  56.189999
# groceries_index                 66.449997
# restaurant_price_index          83.919998
# local_purchasing_power_index    73.540001

# %%
# Remove country duplicates and misspellings
countries_df.country_name = countries_df.country_name.map(lambda x: ssu.country_name_dict.get(x, x))
countries_list = sorted(set(countries_df.country_name).symmetric_difference(set(all_countries_df.country_name)))
if countries_list:
    print(countries_list)
doubles_df = ssu.check_4_doubles(countries_list)
mask_series = (doubles_df.max_similarity > 0.6)
columns_list = ['first_item', 'second_item', 'max_similarity']
if doubles_df[mask_series].shape[0]:
    display(doubles_df[mask_series][columns_list].sort_values('max_similarity', ascending=False))
mask_series = countries_df.duplicated(subset=['country_name'], keep=False)
if countries_df[mask_series].shape[0]:
    display(countries_df[mask_series])
# Out:
# ['Afghanistan', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica', 'Antigua & Barbuda', 'Aruba', 'Benin', 'Bhutan', 'Bonaire, Sint Eustatius & Saba', 'Bouvet Island', 'British Indian Ocean Territory', 'British Virgin Islands', 'Burkina Faso', 'Burundi', 'Cayman Islands', 'Central African Republic', 'Chad', 'Christmas Island', 'Cocos (Keeling) Islands', 'Comoros', 'Cook Islands', 'Curaçao', "Côte d'Ivoire", 'DRC', 'Djibouti', 'Dominica', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Federated States of Micronesia', 'French Guiana', 'French Polynesia', 'French Southern Territories', 'Gabon', 'Gambia', 'Gibraltar', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guinea', 'Guinea-Bissau', 'Haiti', 'Heard Island and McDonald Islands', 'Holy See', 'Isle of Man', 'Ivory Coast', 'Kiribati', 'Kosovo (Disputed Territory)', 'Laos', 'Lesotho', 'Liberia', 'Liechtenstein', 'Madagascar', 'Malawi', 'Mali', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mayotte', 'Monaco', 'Montserrat', 'Mozambique', 'Nauru', 'New Caledonia', 'Niger', 'Niue', 'Norfolk Island', 'North Korea', 'Northern Mariana Islands', 'Palau', 'Papua New Guinea', 'Pitcairn', 'Réunion', 'Saint Helena, Ascension & Tristan da Cunha', 'Samoa', 'San Marino', 'Senegal', 'Seychelles', 'Sierra Leone', 'Sint Maarten', 'Solomon Islands', 'South Georgia and the South Sandwich Islands', 'South Sudan', 'St. Barthélemy', 'St. Kitts & Nevis', 'St. Lucia', 'St. Martin', 'St. Pierre & Miquelon', 'St. Vincent & Grenadines', 'Sudan', 'Suriname', 'Svalbard and Jan Mayen', 'São Tomé & Príncipe', 'Tajikistan', 'Timor-Leste', 'Togo', 'Tokelau', 'Tonga', 'Turkmenistan', 'Turks & Caicos Islands', 'Tuvalu', 'US Virgin Islands', 'United States Minor Outlying Islands', 'Vanuatu', 'Wallis & Futuna', 'Western Sahara', 'Yemen', 'Zambia', 'Åland Islands']
#                   first_item        second_item  max_similarity
# 38                    Gambia             Zambia        0.833333
# 58                    Malawi               Mali        0.800000
# 13    British Virgin Islands  US Virgin Islands        0.769231
# 22              Cook Islands     Norfolk Island        0.769231
# 40                 Greenland            Grenada        0.750000
# 16            Cayman Islands      Åland Islands        0.740741
# 84              Sint Maarten         St. Martin        0.727273
# 85           Solomon Islands      Åland Islands        0.714286
# 3                     Angola           Anguilla        0.714286
# 80                San Marino         St. Martin        0.700000
# 11             Bouvet Island      Faroe Islands        0.692308
# 32             Faroe Islands      Åland Islands        0.692308
# 100                     Togo              Tonga        0.666667
# 69                     Niger               Niue        0.666667
# 98                Tajikistan       Turkmenistan        0.636364
# 44                    Guinea      Guinea-Bissau        0.631579
# 20   Cocos (Keeling) Islands       Cook Islands        0.628571
# 87               South Sudan              Sudan        0.625000
# 71            Norfolk Island    Solomon Islands        0.620690
# 60          Marshall Islands      Åland Islands        0.620690
# 34             French Guiana   French Polynesia        0.620690
# 2                    Andorra             Angola        0.615385

# %%
# These countries cause redditors to make hurtful comments *sniff*
country_set = set(all_countries_df.country_name) - set(ssu.derisable_countries_list)
mask_series = countries_df.country_name.isin(country_set)
countries_df = countries_df[mask_series]

# %%
# Normalize the index so that the US is 100
mask_series = (countries_df.country_name == 'USA')
groceries_index = countries_df[mask_series].groceries_index.squeeze()
countries_df['normalized_groceries_index'] = countries_df.groceries_index.map(lambda x: 100*x/groceries_index)
mask_series = (countries_df.country_name == 'USA')
countries_df[mask_series].T
# Out:
#                                        14
# country_name                          USA
# cost_of_living_index            69.919998
# rent_index                      46.860001
# cost_of_living_plus_rent_index  58.950001
# groceries_index                 70.059998
# restaurant_price_index              65.75
# local_purchasing_power_index    99.879997
# normalized_groceries_index          100.0

# %% [markdown]
# ## Prepare for and Create Choropleth

# %%
equivalence_column_name = 'Country_Equivalent_Groceries_Index'
states_target_column_name = 'grocery_index'
mask_series = countries_df.country_name.isin(all_countries_df.country_name)
ssu.prepare_for_choroplething(countries_df[mask_series], 'normalized_groceries_index', us_states_df,
                              st_col_name=states_target_column_name,
                              st_col_explanation='Groceries Index (2022)',
                              equivalence_column_name=equivalence_column_name, verbose=True)
# Out:
# Albania (39.47) is close to the normalized groceries index of Texas (89.40)
# Algeria (39.05) is close to the normalized groceries index of Texas (89.40)
# Argentina (38.30) is close to the normalized groceries index of Texas (89.40)
# Armenia (48.44) is close to the normalized groceries index of Texas (89.40)
# Australia (103.84) is close to the normalized groceries index of Minnesota (103.90)
# Austria (82.84) is close to the normalized groceries index of Texas (89.40)
# Azerbaijan (36.63) is close to the normalized groceries index of Texas (89.40)
# Bahamas (102.65) is close to the normalized groceries index of Arizona (102.60)
# Bahrain (62.03) is close to the normalized groceries index of Texas (89.40)
# Bangladesh (39.89) is close to the normalized groceries index of Texas (89.40)
# Barbados (116.66) is close to the normalized groceries index of California (117)
# Belarus (34.50) is close to the normalized groceries index of Texas (89.40)
# Belgium (75.89) is close to the normalized groceries index of Texas (89.40)
# Belize (66) is close to the normalized groceries index of Texas (89.40)
# Bermuda (203.57) is close to the normalized groceries index of Hawaii (152.70)
# Bolivia (41.59) is close to the normalized groceries index of Texas (89.40)
# Bosnia & Herzegovina (40.78) is close to the normalized groceries index of Texas (89.40)
# Botswana (46.33) is close to the normalized groceries index of Texas (89.40)
# Brazil (42.81) is close to the normalized groceries index of Texas (89.40)
# Brunei (66.19) is close to the normalized groceries index of Texas (89.40)
# Bulgaria (47.83) is close to the normalized groceries index of Texas (89.40)
# Cambodia (65.66) is close to the normalized groceries index of Texas (89.40)
# Cameroon (47.47) is close to the normalized groceries index of Texas (89.40)
# Canada (97.20) is close to the normalized groceries index of Alabama (97)
# Chile (48.67) is close to the normalized groceries index of Texas (89.40)
# China (61.22) is close to the normalized groceries index of Texas (89.40)
# Colombia (32.80) is close to the normalized groceries index of Texas (89.40)
# Costa Rica (60.52) is close to the normalized groceries index of Texas (89.40)
# Croatia (53.23) is close to the normalized groceries index of Texas (89.40)
# Cuba (69.07) is close to the normalized groceries index of Texas (89.40)
# Cyprus (61.63) is close to the normalized groceries index of Texas (89.40)
# Czechia (53.65) is close to the normalized groceries index of Texas (89.40)
# Denmark (85.56) is close to the normalized groceries index of Texas (89.40)
# Dominican Republic (54.31) is close to the normalized groceries index of Texas (89.40)
# Ecuador (47.03) is close to the normalized groceries index of Texas (89.40)
# Egypt (35.14) is close to the normalized groceries index of Texas (89.40)
# El Salvador (61.70) is close to the normalized groceries index of Texas (89.40)
# Estonia (56.59) is close to the normalized groceries index of Texas (89.40)
# Ethiopia (49.90) is close to the normalized groceries index of Texas (89.40)
# Fiji (62.95) is close to the normalized groceries index of Texas (89.40)
# Finland (80.53) is close to the normalized groceries index of Texas (89.40)
# France (90.17) is close to the normalized groceries index of Michigan (90.40)
# Georgia (43.42) is close to the normalized groceries index of Texas (89.40)
# Germany (69.41) is close to the normalized groceries index of Texas (89.40)
# Ghana (44.36) is close to the normalized groceries index of Texas (89.40)
# Greece (56.08) is close to the normalized groceries index of Texas (89.40)
# Guatemala (57.89) is close to the normalized groceries index of Texas (89.40)
# Guyana (71.81) is close to the normalized groceries index of Texas (89.40)
# Honduras (48.22) is close to the normalized groceries index of Texas (89.40)
# Hungary (44.03) is close to the normalized groceries index of Texas (89.40)
# Iceland (117.67) is close to the normalized groceries index of California (117)
# India (36.48) is close to the normalized groceries index of Texas (89.40)
# Indonesia (50.16) is close to the normalized groceries index of Texas (89.40)
# Iran (40.01) is close to the normalized groceries index of Texas (89.40)
# Iraq (39.65) is close to the normalized groceries index of Texas (89.40)
# Ireland (77.33) is close to the normalized groceries index of Texas (89.40)
# Israel (94.85) is close to the normalized groceries index of Tennessee (94.50)
# Italy (71.24) is close to the normalized groceries index of Texas (89.40)
# Jamaica (75.09) is close to the normalized groceries index of Texas (89.40)
# Japan (95) is close to the normalized groceries index of Virginia (95.40)
# Jordan (56.94) is close to the normalized groceries index of Texas (89.40)
# Kazakhstan (33.87) is close to the normalized groceries index of Texas (89.40)
# Kenya (44.80) is close to the normalized groceries index of Texas (89.40)
# Kuwait (47.47) is close to the normalized groceries index of Texas (89.40)
# Kyrgyzstan (36.30) is close to the normalized groceries index of Texas (89.40)
# Latvia (51.30) is close to the normalized groceries index of Texas (89.40)
# Lebanon (97.30) is close to the normalized groceries index of Alabama (97)
# Libya (35.50) is close to the normalized groceries index of Texas (89.40)
# Lithuania (50.47) is close to the normalized groceries index of Texas (89.40)
# Luxembourg (96.06) is close to the normalized groceries index of Illinois (95.90)
# Malaysia (52.95) is close to the normalized groceries index of Texas (89.40)
# Maldives (75.64) is close to the normalized groceries index of Texas (89.40)
# Malta (72.47) is close to the normalized groceries index of Texas (89.40)
# Mauritius (58.64) is close to the normalized groceries index of Texas (89.40)
# Mexico (49.74) is close to the normalized groceries index of Texas (89.40)
# Moldova (34.88) is close to the normalized groceries index of Texas (89.40)
# Mongolia (49.26) is close to the normalized groceries index of Texas (89.40)
# Montenegro (41.66) is close to the normalized groceries index of Texas (89.40)
# Morocco (37.72) is close to the normalized groceries index of Texas (89.40)
# Myanmar (50.84) is close to the normalized groceries index of Texas (89.40)
# Namibia (47.07) is close to the normalized groceries index of Texas (89.40)
# Nepal (35.13) is close to the normalized groceries index of Texas (89.40)
# Netherlands (82.94) is close to the normalized groceries index of Texas (89.40)
# New Zealand (96.62) is close to the normalized groceries index of North Carolina (96.70)
# Nicaragua (50.97) is close to the normalized groceries index of Texas (89.40)
# Nigeria (47.20) is close to the normalized groceries index of Texas (89.40)
# North Macedonia (35.33) is close to the normalized groceries index of Texas (89.40)
# Norway (116.06) is close to the normalized groceries index of California (117)
# Oman (64.42) is close to the normalized groceries index of Texas (89.40)
# Pakistan (22.51) is close to the normalized groceries index of Texas (89.40)
# Palestine (63) is close to the normalized groceries index of Texas (89.40)
# Panama (67.49) is close to the normalized groceries index of Texas (89.40)
# Paraguay (37.33) is close to the normalized groceries index of Texas (89.40)
# Peru (41.72) is close to the normalized groceries index of Texas (89.40)
# Philippines (47.97) is close to the normalized groceries index of Texas (89.40)
# Poland (40.52) is close to the normalized groceries index of Texas (89.40)
# Portugal (48.24) is close to the normalized groceries index of Texas (89.40)
# Qatar (73.67) is close to the normalized groceries index of Texas (89.40)
# Romania (43.59) is close to the normalized groceries index of Texas (89.40)
# Russia (58.79) is close to the normalized groceries index of Texas (89.40)
# Rwanda (38.10) is close to the normalized groceries index of Texas (89.40)
# Saudi Arabia (60.62) is close to the normalized groceries index of Texas (89.40)
# Serbia (38.24) is close to the normalized groceries index of Texas (89.40)
# Singapore (101.86) is close to the normalized groceries index of North Dakota (101.40)
# Slovakia (54.60) is close to the normalized groceries index of Texas (89.40)
# Slovenia (60.03) is close to the normalized groceries index of Texas (89.40)
# Somalia (49.96) is close to the normalized groceries index of Texas (89.40)
# South Africa (44.38) is close to the normalized groceries index of Texas (89.40)
# South Korea (120.57) is close to the normalized groceries index of New York (121.50)
# Spain (56.31) is close to the normalized groceries index of Texas (89.40)
# Sri Lanka (38.32) is close to the normalized groceries index of Texas (89.40)
# Sweden (78.30) is close to the normalized groceries index of Texas (89.40)
# Switzerland (161.79) is close to the normalized groceries index of Hawaii (152.70)
# Syria (33.77) is close to the normalized groceries index of Texas (89.40)
# Taiwan (95.62) is close to the normalized groceries index of Idaho (95.60)
# Tanzania (40.25) is close to the normalized groceries index of Texas (89.40)
# Thailand (57.81) is close to the normalized groceries index of Texas (89.40)
# Trinidad & Tobago (75.35) is close to the normalized groceries index of Texas (89.40)
# Tunisia (35.56) is close to the normalized groceries index of Texas (89.40)
# Turkiye (33.83) is close to the normalized groceries index of Texas (89.40)
# UAE (66.69) is close to the normalized groceries index of Texas (89.40)
# UK (69.48) is close to the normalized groceries index of Texas (89.40)
# USA (100) is close to the normalized groceries index of Ohio (100.20)
# Uganda (40.95) is close to the normalized groceries index of Texas (89.40)
# Ukraine (38.70) is close to the normalized groceries index of Texas (89.40)
# Uruguay (69.50) is close to the normalized groceries index of Texas (89.40)
# Uzbekistan (36.13) is close to the normalized groceries index of Texas (89.40)
# Venezuela (51.50) is close to the normalized groceries index of Texas (89.40)
# Vietnam (51.91) is close to the normalized groceries index of Texas (89.40)
# Zimbabwe (53.78) is close to the normalized groceries index of Texas (89.40)
#
# Alabama (97) is close to the Groceries Index (2022) of Canada (97.20)
# Alaska (129) is close to the Groceries Index (2022) of South Korea (120.57)
# Arizona (102.60) is close to the Groceries Index (2022) of Bahamas (102.65)
# Arkansas (92.90) is close to the Groceries Index (2022) of Israel (94.85)
# California (117) is close to the Groceries Index (2022) of Barbados (116.66)
# Colorado (96.30) is close to the Groceries Index (2022) of Luxembourg (96.06)
# Connecticut (105.70) is close to the Groceries Index (2022) of Australia (103.84)
# Delaware (106.10) is close to the Groceries Index (2022) of Australia (103.84)
# Florida (106) is close to the Groceries Index (2022) of Australia (103.84)
# Georgia (94.10) is close to the Groceries Index (2022) of Israel (94.85)
# Hawaii (152.70) is close to the Groceries Index (2022) of Switzerland (161.79)
# Idaho (95.60) is close to the Groceries Index (2022) of Taiwan (95.62)
# Illinois (95.90) is close to the Groceries Index (2022) of Luxembourg (96.06)
# Indiana (93.40) is close to the Groceries Index (2022) of Israel (94.85)
# Iowa (99.40) is close to the Groceries Index (2022) of USA (100)
# Kansas (91.70) is close to the Groceries Index (2022) of France (90.17)
# Kentucky (93.70) is close to the Groceries Index (2022) of Israel (94.85)
# Louisiana (96.90) is close to the Groceries Index (2022) of New Zealand (96.62)
# Maine (105.50) is close to the Groceries Index (2022) of Australia (103.84)
# Maryland (109.80) is close to the Groceries Index (2022) of Australia (103.84)
# Massachusetts (111.70) is close to the Groceries Index (2022) of Norway (116.06)
# Michigan (90.40) is close to the Groceries Index (2022) of France (90.17)
# Minnesota (103.90) is close to the Groceries Index (2022) of Australia (103.84)
# Mississippi (92.30) is close to the Groceries Index (2022) of France (90.17)
# Missouri (95.80) is close to the Groceries Index (2022) of Taiwan (95.62)
# Montana (99.40) is close to the Groceries Index (2022) of USA (100)
# Nebraska (97) is close to the Groceries Index (2022) of Canada (97.20)
# Nevada (103) is close to the Groceries Index (2022) of Bahamas (102.65)
# New Hampshire (109.10) is close to the Groceries Index (2022) of Australia (103.84)
# New Jersey (106.20) is close to the Groceries Index (2022) of Australia (103.84)
# New Mexico (100.90) is close to the Groceries Index (2022) of USA (100)
# New York (121.50) is close to the Groceries Index (2022) of South Korea (120.57)
# North Carolina (96.70) is close to the Groceries Index (2022) of New Zealand (96.62)
# North Dakota (101.40) is close to the Groceries Index (2022) of Singapore (101.86)
# Ohio (100.20) is close to the Groceries Index (2022) of USA (100)
# Oklahoma (94) is close to the Groceries Index (2022) of Israel (94.85)
# Oregon (109.30) is close to the Groceries Index (2022) of Australia (103.84)
# Pennsylvania (105.90) is close to the Groceries Index (2022) of Australia (103.84)
# Rhode Island (98.80) is close to the Groceries Index (2022) of USA (100)
# South Carolina (100.20) is close to the Groceries Index (2022) of USA (100)
# South Dakota (104.90) is close to the Groceries Index (2022) of Australia (103.84)
# Tennessee (94.50) is close to the Groceries Index (2022) of Israel (94.85)
# Texas (89.40) is close to the Groceries Index (2022) of France (90.17)
# Utah (100.70) is close to the Groceries Index (2022) of USA (100)
# Vermont (103.70) is close to the Groceries Index (2022) of Australia (103.84)
# Virginia (95.40) is close to the Groceries Index (2022) of Taiwan (95.62)
# Washington (109.70) is close to the Groceries Index (2022) of Australia (103.84)
# West Virginia (98.50) is close to the Groceries Index (2022) of Lebanon (97.30)
# Wisconsin (97.80) is close to the Groceries Index (2022) of Lebanon (97.30)
# Wyoming (105) is close to the Groceries Index (2022) of Australia (103.84)
# Pickling to C:\Users\daveb\OneDrive\Documents\GitHub\StatsByCountry\saves\pkl\us_stats_df.pkl
# Pickling to C:\Users\daveb\OneDrive\Documents\GitHub\StatsByCountry\saves\pkl\column_description_dict.pkl

# %%
c = ChoroplethUtilities(iso_3166_2_code='us', one_country_df=ssu.us_stats_df, all_countries_df=all_countries_df)
c.create_label_line_file()
svg_file_path = c.create_country_colored_labeled_map(
    numeric_column_name=states_target_column_name, string_column_name=equivalence_column_name,
    one_country_df=ssu.us_stats_df, cmap='summer')
print(os.path.abspath(svg_file_path))
# Out:
# C:\Users\daveb\OneDrive\Documents\GitHub\StatsByCountry\saves\svg\US_grocery_index_Country_Equivalent_Groceries_Index.svg
