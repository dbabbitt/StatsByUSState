# %% [markdown]
# # Set up the notebook

# %%
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
import sys

# Insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../py')

from stats_charting_utils import StatsChartingUtilities
from storage import Storage
# %matplotlib inline

# Use the following only if you are on a high definition device
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('retina')

s = Storage()
scu = StatsChartingUtilities(s=s)
us_stats_df = s.load_object('us_stats_df')

# %% [markdown]
# # Find a nice dataset

# %%
# Find a nice-sized dataset that you can represent pixel-by-datapoint
import math

# the sum of the values must equal the total area to be laid out
# i.e., sum(values) == width * height
tuples_list = []
for column_name in us_stats_df.columns:
    try:
        side = math.ceil(math.sqrt(us_stats_df[column_name].sum()))
        side_tuple = (side, column_name)
        tuples_list.append(side_tuple)
    except TypeError as e:
        continue
for (side, column_name) in sorted(tuples_list, key=lambda x: x[0], reverse=True):
    print(f'{column_name}: {side:,} x {side:,}')
# Out:
# gdp_proportion_of_military_expenditures_2021: 866,026 x 866,026
# State_Population: 46,653 x 46,653
# Total_Inhabitants_2010: 17,586 x 17,586
# gdp_millions_usd_2021: 4,802 x 4,802
# gdp_millions_usd_2020: 4,631 x 4,631
# GDP_2018: 4,541 x 4,541
# Guns_Registered: 2,278 x 2,278
# gdp_per_capita_2021: 1,871 x 1,871
# gdp_per_capita_2020: 1,809 x 1,809
# annual_change_usd: 1,273 x 1,273
# total_prison_population: 1,107 x 1,107
# Gun_Suicide_Deaths: 374 x 374
# Suicide_Deaths_2017: 218 x 218
# Suicide_Deaths_2016: 212 x 212
# Suicide_Deaths_2015: 211 x 211
# Suicide_Deaths_2014: 207 x 207
# text_x: 184 x 184
# centroid_x: 182 x 182
# Suicide_Deaths_2005: 181 x 181
# Total_Murder_Deaths_2010: 119 x 119
# text_y: 115 x 115
# centroid_y: 114 x 114
# Inhabitants_Per_Square_Mile_2010: 100 x 100
# Total_Gun_Murder_Deaths_2010: 97 x 97
# Suicide_Rate_2017: 92 x 92
# Suicide_Rate_2016: 89 x 89
# Suicide_Rate_2015: 89 x 89
# Suicide_Rate_2014: 87 x 87
# Suicide_Rate_2005: 79 x 79
# cost_of_living_index: 73 x 73
# grocery_index: 73 x 73
# co2_emissions_mmt: 72 x 72
# Internal_Auditing: 62 x 62
# State_Budget_Processes: 61 x 61
# Procurement: 59 x 59
# State_Pension_Fund_Management: 59 x 59
# Electoral_Oversight: 58 x 58
# Executive_Accountability: 58 x 58
# Legislative_Accountability: 56 x 56
# Lobbying_Disclosure: 56 x 56
# Political_Financing: 55 x 55
# Judicial_Accountability: 55 x 55
# State_Civil_Service_Management: 55 x 55
# Ethics_Enforcement_Entities: 54 x 54
# fertility_rate: 54 x 54
# gini_coefficient: 49 x 49
# Public_Access_to_Information: 47 x 47
# Gun_Ownership_Percent_2013: 41 x 41
# State_FIPS: 39 x 39
# GDP_Rank: 37 x 37
# Guns_Rank: 37 x 37
# Effectiveness_Rank: 36 x 36
# Health_Care_Score: 36 x 36
# Education_Score: 36 x 36
# Economy_Score: 36 x 36
# Infrastructure_Score: 36 x 36
# Opportunity_Score: 36 x 36
# Fiscal_Stability_Score: 36 x 36
# Crime_Corrections_Score: 36 x 36
# Natural_Environment_Score: 36 x 36
# Guns_Per_Capita: 34 x 34
# suicide_rate: 29 x 29
# Fatality Rates per 100,000 Population: 26 x 26
# fatality_rates_per_100k_population: 26 x 26
# font_size: 25 x 25
# Gun_Suicide_Rate: 20 x 20
# real_gdp_growth_percentage: 19 x 19
# Homicide_Rate_1996: 18 x 18
# murder_rates_per_100k_people_2020: 18 x 18
# Homicide_Rate_2018: 16 x 16
# Homicide_Rate_2017: 16 x 16
# Homicide_Rate_2005: 16 x 16
# Homicide_Rate_2000: 16 x 16
# Homicide_Rate_2014: 15 x 15
# Homicide_Rate_2010: 15 x 15
# Murder_Rate_2010: 14 x 14
# annual_change_percentage: 13 x 13
# Gun_Murder_Rate_2010: 12 x 12
# GDP_Percent: 10 x 10
# national_precentage_2021: 10 x 10
# national_precentage_2020: 10 x 10
# total_fertility_rate_2020: 10 x 10
# White_Percent: 6 x 6
# Gini_Index: 6 x 6
# Black_Percent: 3 x 3
# Hispanic_Percent: 3 x 3
# Asian_Percent: 2 x 2
# Multi_Percent: 2 x 2
# co2_emissions_mmt_per_capita: 2 x 2
# Native_Percent: 1 x 1
# Islander_Percent: 1 x 1
# proportion_of_gdp_2021: 1 x 1
# dy: 0 x 0

# %% [markdown]
# # Display Treemap

# %%
size_column_name = 'total_prison_population'
color_column_name = 'White_Percent'
scu.create_colored_labeled_treemap(us_stats_df, size_column_name, color_column_name)
